# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
def load_video(video_path, resize_dim=(320, 240)):
    cap = cv2.VideoCapture(video_path)
    frames = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize frame for faster processing
        resized_frame = cv2.resize(frame, resize_dim)
        frames.append(resized_frame)

    cap.release()
    return frames

# %%
def convert_to_hsv(frame):
    return cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

def noise_detection(frame):
    blurred = cv2.GaussianBlur(frame, (5, 5), 0)
    noise_mask = cv2.absdiff(frame, blurred)
    return noise_mask

# %%
def histogram_comparison(frame1, frame2):
    hist1 = cv2.calcHist([frame1], [0, 1], None, [256, 256], [0, 256, 0, 256])
    hist2 = cv2.calcHist([frame2], [0, 1], None, [256, 256], [0, 256, 0, 256])
    cv2.normalize(hist1, hist1, 0, 1, cv2.NORM_MINMAX)
    cv2.normalize(hist2, hist2, 0, 1, cv2.NORM_MINMAX)


    similarity_score = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
    return similarity_score

# %%
def sobel_edge_detection(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale before Sobel
    sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=5)
    edges = cv2.magnitude(sobel_x, sobel_y)
    return np.uint8(edges)

# %%
def find_least_similarity_cuts(similarity_scores, frames, top_n=5):
    # Get the indices of the least similarity scores (lowest values indicate scene cuts)
    least_similar_indices = np.argsort(similarity_scores)[:top_n]

    print(f"Top {top_n} scene cut frames (by least similarity):")
    for i, idx in enumerate(least_similar_indices):
        print(f"Scene cut {i+1}: between frame {idx} and frame {idx+1} with similarity score: {similarity_scores[idx]}")

        # Display the two consecutive frames where the scene cut occurs
        cv2_imshow(frames[idx])
        cv2_imshow(frames[idx+1])
        cv2.waitKey(1000)  # Wait for a key press to display next set of frames

    return least_similar_indices

# %%
def process_video(video_path, hsv_directory, noise_directory, edge_directory, top_n_cuts=5, resize_dim=(320, 240)):
    if not os.path.exists(hsv_directory):
        os.makedirs(hsv_directory)
    if not os.path.exists(noise_directory):
         os.makedirs(noise_directory)
    if not os.path.exists(edge_directory):
         os.makedirs(edge_directory)

    frames = load_video(video_path, resize_dim=resize_dim)
    hsv_frames = []
    noise_frames = []
    edge_frames = []
    similarity_scores = []

    for idx, frame in enumerate(frames):
        # Step 2: Convert each frame into HSV
        hsv_frame = convert_to_hsv(frame)
        hsv_frames.append(hsv_frame)
        cv2.imwrite(os.path.join(hsv_directory, f'hsv_frame_{idx}.png'), hsv_frame)

        # Step 3: Detect noise
        noise_frame = noise_detection(frame)
        noise_frames.append(noise_frame)
        cv2.imwrite(os.path.join(noise_directory, f'noise_frame_{idx}.png'), noise_frame)

        # Step 4: Perform histogram comparison with the previous frame
        if idx > 0:
            similarity = histogram_comparison(frames[idx-1], frames[idx])
            similarity_scores.append(similarity)
            print(f'Similarity between frame {idx-1} and frame {idx}: {similarity}')

        # Step 5: Perform edge detection
        edge_frame = sobel_edge_detection(frame)
        edge_frames.append(edge_frame)
        cv2.imwrite(os.path.join(edge_directory, f'edge_frame_{idx}.png'), edge_frame)

    # Step 6: Find least similarity cuts and display the frames
    if len(similarity_scores) > 0:
        least_similar_indices = find_least_similarity_cuts(similarity_scores, frames, top_n_cuts)

        # Optionally, save the frames at the scene cut points for analysis
        for i, idx in enumerate(least_similar_indices):
            cv2.imwrite(os.path.join(hsv_directory, f'scene_cut_frame_{i+1}frame{idx}.png'), frames[idx])
            cv2.imwrite(os.path.join(hsv_directory, f'scene_cut_frame_{i+1}frame{idx+1}.png'), frames[idx+1])

# %%
video_path = r"/content/videoplayback.mp4"
hsv_directory = r"/content/hsv_frames"
noise_directory = r"/content/noise_frames"
edge_directory = r"/content/edge_frames"
process_video(video_path, hsv_directory, noise_directory, edge_directory, top_n_cuts=5, resize_dim=(320, 240))
# Out:
# Similarity between frame 0 and frame 1: 0.6863895971522007
# Similarity between frame 1 and frame 2: 0.661135397050045
# Similarity between frame 2 and frame 3: 0.6490698315351081
# Similarity between frame 3 and frame 4: 0.6375295040837177
# Similarity between frame 4 and frame 5: 0.6740614953956098
# Similarity between frame 5 and frame 6: 0.5968762355028282
# Similarity between frame 6 and frame 7: 0.565655031050572
# Similarity between frame 7 and frame 8: 0.5408691991936723
# Similarity between frame 8 and frame 9: 0.49628419211517694
# Similarity between frame 9 and frame 10: 0.5030121635821571
# Similarity between frame 10 and frame 11: 0.5106644200667287
# Similarity between frame 11 and frame 12: 0.4340201479740547
# Similarity between frame 12 and frame 13: 0.3946047729548212
# Similarity between frame 13 and frame 14: 0.38929292953342515
# Similarity between frame 14 and frame 15: 0.3664447564187704
# Similarity between frame 15 and frame 16: 0.30401085354635937
# Similarity between frame 16 and frame 17: 0.9753891872933736
# Similarity between frame 17 and frame 18: 0.9795475462635297
# Similarity between frame 18 and frame 19: 0.9812620271870433
# Similarity between frame 19 and frame 20: 0.9858604797604551
# Similarity between frame 20 and frame 21: 0.9850841106214313
# Similarity between frame 21 and frame 22: 0.9845548762031235
# Similarity between frame 22 and frame 23: 0.9885817210542746
# Similarity between frame 23 and frame 24: 0.9862842572437887
# Similarity between frame 24 and frame 25: 0.9940077646065416
# Similarity between frame 25 and frame 26: 0.989894173262459
# Similarity between frame 26 and frame 27: 0.9899110550814011
# Similarity between frame 27 and frame 28: 0.991626513417231
# Similarity between frame 28 and frame 29: 0.9927962419326968
# Similarity between frame 29 and frame 30: 0.9903276173415814
# Similarity between frame 30 and frame 31: 0.9933802604190379
# Similarity between frame 31 and frame 32: 0.9918979435636426
# Similarity between frame 32 and frame 33: 0.995599565640553
# Similarity between frame 33 and frame 34: 0.9948749909118922
# Similarity between frame 34 and frame 35: 0.9950827265575076
# Similarity between frame 35 and frame 36: 0.9946300960837107
# Similarity between frame 36 and frame 37: 0.9952233819080925
# Similarity between frame 37 and frame 38: 0.994716603069781
# Similarity between frame 38 and frame 39: 0.9917814761873661
# Similarity between frame 39 and frame 40: 0.9926917418880242
# Similarity between frame 40 and frame 41: 0.9930218115410631
# Similarity between frame 41 and frame 42: 0.9917241631001404
# Similarity between frame 42 and frame 43: 0.9919318033461566
# Similarity between frame 43 and frame 44: 0.990459798317625
# Similarity between frame 44 and frame 45: 0.9905515759170194
# Similarity between frame 45 and frame 46: 0.9913077992627892
# Similarity between frame 46 and frame 47: 0.9928418480845479
# Similarity between frame 47 and frame 48: 0.9881106268827023
# Similarity between frame 48 and frame 49: 0.9927052257259354
# Similarity between frame 49 and frame 50: 0.9922241393041491
# Similarity between frame 50 and frame 51: 0.9916176885191912
# Similarity between frame 51 and frame 52: 0.9909716771521933
# Similarity between frame 52 and frame 53: 0.994288958570187
# Similarity between frame 53 and frame 54: 0.9914453523251315
# Similarity between frame 54 and frame 55: 0.9952861545987057
# Similarity between frame 55 and frame 56: 0.9968479691532801
# Similarity between frame 56 and frame 57: 0.9970543910938627
# Similarity between frame 57 and frame 58: 0.4112451165319628
# Similarity between frame 58 and frame 59: 0.32522701572111823
# Similarity between frame 59 and frame 60: 0.40706006232973807
# Similarity between frame 60 and frame 61: 0.347708951151087
# Similarity between frame 61 and frame 62: 0.4050929211317994
# Similarity between frame 62 and frame 63: 0.3589269207646639
# Similarity between frame 63 and frame 64: 0.4028827512141132
# Similarity between frame 64 and frame 65: 0.3090536449525376
# Similarity between frame 65 and frame 66: 0.28460786133943405
# Similarity between frame 66 and frame 67: 0.296742409649658
# Similarity between frame 67 and frame 68: 0.31727810702845755
# Similarity between frame 68 and frame 69: 0.23312972971431897
# Similarity between frame 69 and frame 70: 0.13365128794820588
# Similarity between frame 70 and frame 71: 0.08586030856986783
# Similarity between frame 71 and frame 72: 0.0819940817100581
# Similarity between frame 72 and frame 73: 0.991721512861505
# Similarity between frame 73 and frame 74: 0.9980177789111616
# Similarity between frame 74 and frame 75: 0.9992264450928733
# Similarity between frame 75 and frame 76: 0.9980758575505863
# Similarity between frame 76 and frame 77: 0.9994343752232581
# Similarity between frame 77 and frame 78: 0.050563462813981566
# Similarity between frame 78 and frame 79: 0.9880287740286156
# Similarity between frame 79 and frame 80: 0.9862418211975693
# Similarity between frame 80 and frame 81: 0.9865198331911302
# Similarity between frame 81 and frame 82: 0.9895182443297159
# Similarity between frame 82 and frame 83: 0.9830748208532614
# Similarity between frame 83 and frame 84: 0.9859895954522753
# Similarity between frame 84 and frame 85: 0.9839353319985182
# Similarity between frame 85 and frame 86: 0.9846662633722282
# Similarity between frame 86 and frame 87: 0.9826737144058708
# Similarity between frame 87 and frame 88: 0.9824666138569288
# Similarity between frame 88 and frame 89: 0.9887836805660338
# Similarity between frame 89 and frame 90: 0.9833270178793669
# Similarity between frame 90 and frame 91: 0.9858926756657307
# Similarity between frame 91 and frame 92: 0.9841218408978271
# Similarity between frame 92 and frame 93: 0.982574748064669
# Similarity between frame 93 and frame 94: 0.9847279477605965
# Similarity between frame 94 and frame 95: 0.9847332718416174
# Similarity between frame 95 and frame 96: 0.9874207315354104
# Similarity between frame 96 and frame 97: 0.9848929643239428
# Similarity between frame 97 and frame 98: 0.9818367136539105
# Similarity between frame 98 and frame 99: 0.9870964093904834
# Similarity between frame 99 and frame 100: 0.9888281117263382
# Similarity between frame 100 and frame 101: 0.9906552899662554
# Similarity between frame 101 and frame 102: 0.9908522713930943
# Similarity between frame 102 and frame 103: 0.9862592993294135
# Similarity between frame 103 and frame 104: 0.9821144949384443
# Similarity between frame 104 and frame 105: 0.9837103947315712
# Similarity between frame 105 and frame 106: 0.9776275427094504
# Similarity between frame 106 and frame 107: 0.9805055669244622
# Similarity between frame 107 and frame 108: 0.9802477812537722
# Similarity between frame 108 and frame 109: 0.9718150867399061
# Similarity between frame 109 and frame 110: 0.9783376442798158
# Similarity between frame 110 and frame 111: 0.9806773695651249
# Similarity between frame 111 and frame 112: 0.9827369786367032
# Similarity between frame 112 and frame 113: 0.978394716259793
# Similarity between frame 113 and frame 114: 0.9756528170543977
# Similarity between frame 114 and frame 115: 0.9785602335281313
# Similarity between frame 115 and frame 116: 0.9788747574657879
# Similarity between frame 116 and frame 117: 0.9767494632907187
# Similarity between frame 117 and frame 118: 0.9656233805025559
# Similarity between frame 118 and frame 119: 0.9842949030427189
# Similarity between frame 119 and frame 120: 0.9830920025831293
# Similarity between frame 120 and frame 121: 0.9795259841675301
# Similarity between frame 121 and frame 122: 0.972967661942595
# Similarity between frame 122 and frame 123: 0.9735032349826063
# Similarity between frame 123 and frame 124: 0.8864213387299521
# Similarity between frame 124 and frame 125: 0.9737296637016944
# Similarity between frame 125 and frame 126: 0.9762901537920803
# Similarity between frame 126 and frame 127: 0.9654524227409865
# Similarity between frame 127 and frame 128: 0.9667914077764744
# Similarity between frame 128 and frame 129: 0.9610413898758673
# Similarity between frame 129 and frame 130: 0.9775231001225397
# Similarity between frame 130 and frame 131: 0.9758779218205565
# Similarity between frame 131 and frame 132: 0.9866663596005102
# Similarity between frame 132 and frame 133: 0.08452728700831584
# Similarity between frame 133 and frame 134: 0.9846836018475226
# Similarity between frame 134 and frame 135: 0.9858388343443184
# Similarity between frame 135 and frame 136: 0.9839288905631252
# Similarity between frame 136 and frame 137: 0.9815258416701603
# Similarity between frame 137 and frame 138: 0.9805341444253375
# Similarity between frame 138 and frame 139: 0.9775096916818015
# Similarity between frame 139 and frame 140: 0.977197279958178
# Similarity between frame 140 and frame 141: 0.9776271658370437
# Similarity between frame 141 and frame 142: 0.9747382761625271
# Similarity between frame 142 and frame 143: 0.9736956658781204
# Similarity between frame 143 and frame 144: 0.9751282400089734
# Similarity between frame 144 and frame 145: 0.9721511269926946
# Similarity between frame 145 and frame 146: 0.9739125569497424
# Similarity between frame 146 and frame 147: 0.9739217804217482
# Similarity between frame 147 and frame 148: 0.9677750388480748
# Similarity between frame 148 and frame 149: 0.9715732340553586
# Similarity between frame 149 and frame 150: 0.9717731763099344
# Similarity between frame 150 and frame 151: 0.9709048246563536
# Similarity between frame 151 and frame 152: 0.9732490636082097
# Similarity between frame 152 and frame 153: 0.9742891135239753
# Similarity between frame 153 and frame 154: 0.9734000477106648
# Similarity between frame 154 and frame 155: 0.9722851811121355
# Similarity between frame 155 and frame 156: 0.9717497456532541
# Similarity between frame 156 and frame 157: 0.9744157838768953
# Similarity between frame 157 and frame 158: 0.9755456790931392
# Similarity between frame 158 and frame 159: 0.9772549229072772
# Similarity between frame 159 and frame 160: 0.9762560465055482
# Similarity between frame 160 and frame 161: 0.978637347604899
# Similarity between frame 161 and frame 162: 0.9780467759142
# Similarity between frame 162 and frame 163: 0.9783702709762203
# Similarity between frame 163 and frame 164: 0.9775288856641218
# Similarity between frame 164 and frame 165: 0.9786565381974643
# Similarity between frame 165 and frame 166: 0.9782676468940041
# Similarity between frame 166 and frame 167: 0.9800700208475307
# Similarity between frame 167 and frame 168: 0.978660058675956
# Similarity between frame 168 and frame 169: 0.9741090776931465
# Similarity between frame 169 and frame 170: 0.9764729523173322
# Similarity between frame 170 and frame 171: 0.9766501943363776
# Similarity between frame 171 and frame 172: 0.9751100151771215
# Similarity between frame 172 and frame 173: 0.9784028668162107
# Similarity between frame 173 and frame 174: 0.9792467701323854
# Similarity between frame 174 and frame 175: 0.9778549629206797
# Similarity between frame 175 and frame 176: 0.9778085565021879
# Similarity between frame 176 and frame 177: 0.9802104172552151
# Similarity between frame 177 and frame 178: 0.9807752545651155
# Similarity between frame 178 and frame 179: 0.97734378865546
# Similarity between frame 179 and frame 180: 0.9775449527548682
# Similarity between frame 180 and frame 181: 0.9797946993982498
# Similarity between frame 181 and frame 182: 0.9807507872415673
# Similarity between frame 182 and frame 183: 0.9786382298970205
# Similarity between frame 183 and frame 184: 0.9755825915095659
# Similarity between frame 184 and frame 185: 0.9814734048783265
# Similarity between frame 185 and frame 186: 0.980785962065463
# Similarity between frame 186 and frame 187: 0.9816136321127892
# Similarity between frame 187 and frame 188: 0.9787957346058817
# Similarity between frame 188 and frame 189: 0.9822660993343766
# Similarity between frame 189 and frame 190: 0.9813239529596309
# Similarity between frame 190 and frame 191: 0.9799688712113708
# Similarity between frame 191 and frame 192: 0.9808482228831885
# Similarity between frame 192 and frame 193: 0.9832292110000544
# Similarity between frame 193 and frame 194: 0.9805255807555756
# Similarity between frame 194 and frame 195: 0.9767874054859462
# Similarity between frame 195 and frame 196: 0.9727075499771547
# Similarity between frame 196 and frame 197: 0.9806472894532339
# Similarity between frame 197 and frame 198: 0.9776380948858219
# Similarity between frame 198 and frame 199: 0.978095997053641
# Similarity between frame 199 and frame 200: 0.9782590009914107
# Similarity between frame 200 and frame 201: 0.9779487994883984
# Similarity between frame 201 and frame 202: 0.9743367334294618
# Similarity between frame 202 and frame 203: 0.9771135573627188
# Similarity between frame 203 and frame 204: 0.9779615319332208
# Similarity between frame 204 and frame 205: 0.979557564115624
# Similarity between frame 205 and frame 206: 0.971591768244504
# Similarity between frame 206 and frame 207: 0.9751728300285554
# Similarity between frame 207 and frame 208: 0.9726692858653407
# Similarity between frame 208 and frame 209: 0.9755224481097219
# Similarity between frame 209 and frame 210: 0.9743989282981813
# Similarity between frame 210 and frame 211: 0.9726481991004067
# Similarity between frame 211 and frame 212: 0.9713422097560536
# Similarity between frame 212 and frame 213: 0.9737495017001503
# Similarity between frame 213 and frame 214: 0.9709655322528461
# Similarity between frame 214 and frame 215: 0.9738014874094991
# Similarity between frame 215 and frame 216: 0.975936075571917
# Similarity between frame 216 and frame 217: 0.9763014640213119
# Similarity between frame 217 and frame 218: 0.9721017750091878
# Similarity between frame 218 and frame 219: 0.9802990349156515
# Similarity between frame 219 and frame 220: 0.9780761666879683
# Similarity between frame 220 and frame 221: 0.9810517852820096
# Similarity between frame 221 and frame 222: 0.9829894759192492
# Similarity between frame 222 and frame 223: 0.9843005316456775
# Similarity between frame 223 and frame 224: 0.9827278787377539
# Similarity between frame 224 and frame 225: 0.981825865416863
# Similarity between frame 225 and frame 226: 0.9841030093649402
# Similarity between frame 226 and frame 227: 0.9865061692764808
# Similarity between frame 227 and frame 228: 0.9878362014672943
# Similarity between frame 228 and frame 229: 0.9885056903333688
# Similarity between frame 229 and frame 230: 0.9833911321304925
# Similarity between frame 230 and frame 231: 0.9900397156870887
# Similarity between frame 231 and frame 232: 0.9898834241652607
# Similarity between frame 232 and frame 233: 0.9900503616267357
# Similarity between frame 233 and frame 234: 0.9873490603940432
# Similarity between frame 234 and frame 235: 0.9925220396950863
# Similarity between frame 235 and frame 236: 0.9897820651395055
# Similarity between frame 236 and frame 237: 0.9929058247955558
# Similarity between frame 237 and frame 238: 0.9897221141703701
# Similarity between frame 238 and frame 239: 0.9925538222614789
# Similarity between frame 239 and frame 240: 0.9924012239027508
# Similarity between frame 240 and frame 241: 0.05003248718049006
# Similarity between frame 241 and frame 242: 0.9792340922593912
# Similarity between frame 242 and frame 243: 0.9783828518887083
# Similarity between frame 243 and frame 244: 0.9806424477943801
# Similarity between frame 244 and frame 245: 0.9775506106392868
# Similarity between frame 245 and frame 246: 0.9797077641923712
# Similarity between frame 246 and frame 247: 0.9768337889208724
# Similarity between frame 247 and frame 248: 0.9799961062724484
# Similarity between frame 248 and frame 249: 0.9787590961794412
# Similarity between frame 249 and frame 250: 0.9767221737964507
# Similarity between frame 250 and frame 251: 0.9180607194374437
# Similarity between frame 251 and frame 252: 0.9734771441143624
# Similarity between frame 252 and frame 253: 0.9679457037296566
# Similarity between frame 253 and frame 254: 0.9647926375667508
# Similarity between frame 254 and frame 255: 0.7651943761015703
# Similarity between frame 255 and frame 256: 0.8976451392078577
# Similarity between frame 256 and frame 257: 0.9354813131239188
# Similarity between frame 257 and frame 258: 0.9214590989409619
# Similarity between frame 258 and frame 259: 0.8821823547950756
# Similarity between frame 259 and frame 260: 0.9219739899999726
# Similarity between frame 260 and frame 261: 0.9242124566325786
# Similarity between frame 261 and frame 262: 0.9213729648523844
# Similarity between frame 262 and frame 263: 0.89261866760452
# Similarity between frame 263 and frame 264: 0.9407221506347313
# Similarity between frame 264 and frame 265: 0.9428530487467401
# Similarity between frame 265 and frame 266: 0.9551549051506925
# Similarity between frame 266 and frame 267: 0.902073551495219
# Similarity between frame 267 and frame 268: 0.9555583468854237
# Similarity between frame 268 and frame 269: 0.9583688730165967
# Similarity between frame 269 and frame 270: 0.9638759956559428
# Similarity between frame 270 and frame 271: 0.9247632657110293
# Similarity between frame 271 and frame 272: 0.9623951797332074
# Similarity between frame 272 and frame 273: 0.05263124598861338
# Similarity between frame 273 and frame 274: 0.9948137694397239
# Similarity between frame 274 and frame 275: 0.9941235906312064
# Similarity between frame 275 and frame 276: 0.9992493377741631
# Similarity between frame 276 and frame 277: 0.9944019119993464
# Similarity between frame 277 and frame 278: 0.9951215647714273
# Similarity between frame 278 and frame 279: 0.9936630744516586
# Similarity between frame 279 and frame 280: 0.9935647191301663
# Similarity between frame 280 and frame 281: 0.9931507839345047
# Similarity between frame 281 and frame 282: 0.9937669485724023
# Similarity between frame 282 and frame 283: 0.993065957140456
# Similarity between frame 283 and frame 284: 0.9909550636458152
# Similarity between frame 284 and frame 285: 0.9920820953488928
# Similarity between frame 285 and frame 286: 0.9997031936365542
# Similarity between frame 286 and frame 287: 0.9926809808938564
# Similarity between frame 287 and frame 288: 0.9924884515227451
# Similarity between frame 288 and frame 289: 0.9908945465759494
# Similarity between frame 289 and frame 290: 0.9922581129652024
# Similarity between frame 290 and frame 291: 0.9927045458449674
# Similarity between frame 291 and frame 292: 0.992706193323208
# Similarity between frame 292 and frame 293: 0.9891688120396003
# Similarity between frame 293 and frame 294: 0.9930097310247368
# Similarity between frame 294 and frame 295: 0.9919809675533168
# Similarity between frame 295 and frame 296: 0.9995137652616367
# Similarity between frame 296 and frame 297: 0.9947240855413984
# Similarity between frame 297 and frame 298: 0.9924357880970391
# Similarity between frame 298 and frame 299: 0.990891217975479
# Similarity between frame 299 and frame 300: 0.9910939146013907
# Similarity between frame 300 and frame 301: 0.9921300975645873
# Similarity between frame 301 and frame 302: 0.9920318322290942
# Similarity between frame 302 and frame 303: 0.9917839084562731
# Similarity between frame 303 and frame 304: 0.9917349696773189
# Similarity between frame 304 and frame 305: 0.9917424268271993
# Similarity between frame 305 and frame 306: 0.9996828730354422
# Similarity between frame 306 and frame 307: 0.99383767236764
# Similarity between frame 307 and frame 308: 0.0011099933079387315
# Similarity between frame 308 and frame 309: 1.0
# Similarity between frame 309 and frame 310: 1.0
# Similarity between frame 310 and frame 311: 1.0
# Similarity between frame 311 and frame 312: 1.0
# Similarity between frame 312 and frame 313: 1.0
# Similarity between frame 313 and frame 314: 1.0
# Similarity between frame 314 and frame 315: 1.0
# Similarity between frame 315 and frame 316: 1.0
# Similarity between frame 316 and frame 317: 1.0
# Similarity between frame 317 and frame 318: 1.0
# Similarity between frame 318 and frame 319: 1.0
# Similarity between frame 319 and frame 320: 1.0
# Similarity between frame 320 and frame 321: 1.0
# Similarity between frame 321 and frame 322: 1.0
# Similarity between frame 322 and frame 323: 1.0
# Similarity between frame 323 and frame 324: 1.0
# Similarity between frame 324 and frame 325: 1.0
# Similarity between frame 325 and frame 326: 1.0
# Similarity between frame 326 and frame 327: 1.0
# Similarity between frame 327 and frame 328: 1.0
# Similarity between frame 328 and frame 329: 1.0
# Similarity between frame 329 and frame 330: 1.0
# Similarity between frame 330 and frame 331: 1.0
# Similarity between frame 331 and frame 332: 1.0
# Similarity between frame 332 and frame 333: 1.0
# Similarity between frame 333 and frame 334: 1.0
# Similarity between frame 334 and frame 335: 1.0
# Similarity between frame 335 and frame 336: 1.0
# Similarity between frame 336 and frame 337: 1.0
# Similarity between frame 337 and frame 338: 1.0
# Similarity between frame 338 and frame 339: 1.0
# Similarity between frame 339 and frame 340: 0.999995596797935
# Similarity between frame 340 and frame 341: 0.9999999738326235
# Similarity between frame 341 and frame 342: 1.0
# Similarity between frame 342 and frame 343: 1.0
# Similarity between frame 343 and frame 344: 1.0
# Similarity between frame 344 and frame 345: 1.0
# Similarity between frame 345 and frame 346: 1.0
# Similarity between frame 346 and frame 347: 1.0
# Similarity between frame 347 and frame 348: 1.0
# Similarity between frame 348 and frame 349: 1.0
# Similarity between frame 349 and frame 350: 1.0
# Similarity between frame 350 and frame 351: 1.0
# Similarity between frame 351 and frame 352: 1.0
# Similarity between frame 352 and frame 353: 1.0
# Similarity between frame 353 and frame 354: 1.0
# Similarity between frame 354 and frame 355: 1.0
# Similarity between frame 355 and frame 356: 1.0
# Similarity between frame 356 and frame 357: 1.0
# Similarity between frame 357 and frame 358: 1.0
# Similarity between frame 358 and frame 359: 1.0
# Top 5 scene cut frames (by least similarity):
# Scene cut 1: between frame 307 and frame 308 with similarity score: 0.0011099933079387315
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 2: between frame 240 and frame 241 with similarity score: 0.05003248718049006
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 3: between frame 77 and frame 78 with similarity score: 0.050563462813981566
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 4: between frame 272 and frame 273 with similarity score: 0.05263124598861338
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 5: between frame 71 and frame 72 with similarity score: 0.0819940817100581
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
